# %% [markdown]
# <h3> Basic Statistics </h3>
# References
# https://docs.python.org/3/library/statistics.html#statistics.stdev
#
# https://docs.scipy.org/doc/numpy-1.13.0/index.html
#
# http://www.itl.nist.gov/div898/handbook/eda/section3/eda362.htm

# %%
import statistics
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3> Variance </h3>
# Variance is a measure of the variability (spread or dispersion) of data. A large variance indicates that the data is spread out; a small variance indicates it is clustered closely around the mean. The variance of $n$ data points with mean $\mu$ is given by:
#
# $$\sigma^2 = \frac{\displaystyle\sum_{i=1}^{n}(x_i - \mu)^2} {n-1}$$
#
# <h3> Standard Deviation ($\sigma$) </h3>
# It is square root of variance.

# %%
#using numpy
X = np.random.randint(50, size=10)
#X = np.array([21, 36, 17, 16, 24, 30, 39, 39, 42, 42])
print (X)
Xm = np.mean(X)
print (Xm)
var = 0.0
for i in range(10):
    var = var + (X[i]-Xm)*(X[i]-Xm)
var = var/9.0
print (var)    

print (np.var(X, ddof=1))
print(np.std(X,ddof=1), np.sqrt(np.var(X,ddof=1)))
# Out:
# [22 22 38  7 48 31 40 41 48 33]
# 33.0
# 167.77777777777777
# 167.77777777777777
# 12.952906151816965 12.952906151816965

# %% [markdown]
# ### Chebyshev's inequality
# Examples from Quantopian Notebook
# There are no more than $1/k^2$ of a given distribution that are more than $k$ standard deviations away from the mean.

# %%
X = np.random.randint(100, size=20)
print (X)
xm = np.mean(X)
k = np.sqrt(2)
#k = 1.2
dist = k*np.std(X) # k standard deviation
val_out = [x for x in X if abs(x - xm) >= dist]
print ('Number of values greater than ', k, 'standard deviations away from the mean:', val_out)
print ('Chebyshev\'s inequality hold for X:', float(len(val_out))/len(X), '<', 1/k**2)
# Out:
# [62 21 51 86 20 80 10 85 65  4 40  5 66 81 15 37 31 52 94 27]
# Number of values greater than  1.4142135623730951 standard deviations away from the mean: [4, 5, 94]
# Chebyshev's inequality hold for X: 0.15 < 0.4999999999999999

# %% [markdown]
# Exercise 1: Another way to look at the Chebyshev's inequality is to state the there are at least $1 - 1/k^2$ distribution values lies within “plus or minus” k standard deviations σ of the mean µ. For a randomly generated data of size 1000 as in the earlier experiment, show that 36% of the randomly generated values lie within “plus or minus” 1.25 standard deviations σ of the mean µ.

# %%
# Complete the solution
# Note that k here is 1.25
k = 1.25
X = np.random.randint(100, size=1000)
xm = np.mean(X)
dist = k*np.std(X)
print(dist)
val_out = [x for x in X if abs(x - xm) <= dist]

print ("Number of values meeting the constraint (in fraction of total) ", float(len(val_out))/len(X))
print ("Chebyshev's Inequality States: ",1 - 1/k**2  )       
print('Values lie between:', -dist,'<',1-(1/k**2),'<',+dist)
print(int((1-(1/k**2))*100),'% of the values are lying between',-dist,'and',+dist)
# Out:
# 36.22757711674906
# Number of values meeting the constraint (in fraction of total)  0.724
# Chebyshev's Inequality States:  0.36
# Values lie between: -36.22757711674906 < 0.36 < 36.22757711674906
# 36 % of the values are lying between -36.22757711674906 and 36.22757711674906

# %% [markdown]
# <h3> Covariance </h3>
# Covariance of two random variables measure how the two variables move together. If they move in the same direction the covariance is positive and if they move in opposite direction the covariance is negative.
#
# $cov_{x,y}=\frac{\sum_{i=1}^{N}(x_{i}-\bar{x})(y_{i}-\bar{y})}{N-1}$

# %%
X = np.array([0.1, 0.3, 0.4, 0.8, 0.9])
Y = np.array([1.2, 2.4, 2.6, 3.0, 5.5])
Xm = np.mean(X)
Ym = np.mean(Y)
s = 0.0
for i in range(5):
    s = s+ (X[i]-Xm)*(Y[i]-Ym)
cov_xy = s/4.0
print (cov_xy)
# Out:
# 0.47000000000000003

# %%
X = np.array([0.1, 0.3, 0.4, 0.8, 0.9])
Y = np.array([5.5,  3.0, 2.6,  2.4, 1.2])
Xm = np.mean(X)
Ym = np.mean(Y)
s = 0.0
for i in range(5):
    s = s+ (X[i]-Xm)*(Y[i]-Ym)
cov_xy = s/4.0
print (cov_xy)
# Out:
# -0.4650000000000001

# %% [markdown]
# <h3> Covariance Matrix </h3>
#
# \begin{matrix}
#   cov_{x,x} & cov_{x,y} \\
#   cov_{y,x} & cov_{y,y}
#  \end{matrix}

# %%
#cov(x,x)
cov_xx = np.var(X) 
#cov(y,y)
cov_yy = np.var(Y)
#cov(y,x) = cov(x,y)
cov_yx = cov_xy
cov_mat = [[ cov_xx,  cov_xy ],[ cov_yx,   cov_yy]]
print (cov_mat)
# Out:
# [[0.09200000000000001, -0.4650000000000001], [-0.4650000000000001, 1.9983999999999997]]

# %%
# using numpy
D = np.array([ [0.1, 0.3, 0.4, 0.8, 0.9],
               [5.5,  3.0, 2.6,  2.4, 1.2]
             ])
print( np.cov(D)) 
print( np.cov(D)[0,0])
# Out:
# [[ 0.115 -0.465]
#  [-0.465  2.498]]
# 0.11500000000000003

# %% [markdown]
# <h3> Coorelation </h3>
#
# Coorelation is obtained by normalizing covariance by the standard deviation. This is particularly useful when the variables ($x$ and $y$) are on different scales.
#
# $\rho = \frac{cov_{x,y}}{\sigma_x \sigma_y}$

# %%
stdx  = math.sqrt(cov_xx)
stdy  = math.sqrt(cov_yy)
corr_xy = cov_xy/(stdx*stdy)
corr_yx = corr_xy
print (corr_xy)
corr_xx = cov_xx/(stdx*stdx)
corr_yy = cov_yy/(stdy*stdy)
print (corr_xx, corr_yy)
corr_mat = [[ corr_xx,  corr_xy ],[ corr_yx,   corr_yy]]
print (corr_mat)
# Out:
# -1.0844707146576056
# 1.0 1.0000000000000002
# [[1.0, -1.0844707146576056], [-1.0844707146576056, 1.0000000000000002]]

# %%
# using numpy
D = np.array([ [0.1, 0.3, 0.4, 0.8, 0.9],
               [5.5,  3.0, 2.6,  2.4, 1.2]
             ])
print( np.corrcoef(D) )
# Out:
# [[ 1.         -0.86757657]
#  [-0.86757657  1.        ]]

# %% [markdown]
# #### Example Random Data

# %%
X = np.random.rand(50)
Y = np.random.rand(50)

plt.scatter(X,Y)
plt.xlabel('X Value')
plt.ylabel('Y Value')

# we use only one off-diagonal entry from the matrix 
print ('Correlation: ', np.cov(X,Y)[0,1]/(np.std(X)*np.std(Y)) )
#  using corrcoef function
print ('Correlation using corrcoeff: ', np.corrcoef(X, Y)[0, 1]) 
plt.show()
# Out:
# Correlation:  -0.150237198453696
# Correlation using corrcoeff:  -0.14723245448462208

# %%
# generate correlated data
X = np.random.rand(50)
Y = X + np.random.normal(0, 0.1, 50)


plt.scatter(X,Y)
plt.xlabel('X Value')
plt.ylabel('Y Value')
print ('Correlation using corrcoeff: ', np.corrcoef(X, Y)[0, 1]) 
plt.show()
# Out:
# Correlation using corrcoeff:  0.9413768200917279

# %%
# less coorelated (add more noise)
X = np.random.rand(50)
Y = X + np.random.normal(0, .2, 50)

plt.scatter(X,Y)
plt.xlabel('X Value')
plt.ylabel('Y Value')
print ('Correlation using corrcoeff: ', np.corrcoef(X, Y)[0, 1]) 
plt.show()
# Out:
# Correlation using corrcoeff:  0.8455858667233216

# %% [markdown]
# Exercise 2 : Correlation is heavily used in the finance industry. One use is in building a portfolio with reduced risk. This is typically accomplished by having uncorrelated stocks in the portfolio. Another use is to identify a pair of stocks that are correlated and use it to predict stock price. In this exercise, we will compute correlation coefficient between two stocks simple returns. Get daily historical data for last two years years for AAPL and SPY from the yahoo finance site: https://finance.yahoo.com/ (At the yahoo finance site search for a stock symbol and you will see links for historical data). Download the historical finance data for two stocks and save it into two separate  csv files. Write Python code to read the adjusted price of the two stocks from csv files, compute correlation coefficient, and plot a scatter-plot of the returns.
#
# Note that a simple return $r_i$ for an asset at time $t_i$ for one unit of time is given by:
# \begin{equation*}
# r_i = \frac{S_i - S_{i-1}}{S_{i-1}}
# \end{equation*}
# Where $S_{i-1}$ and $S_i$  be the price of a stock at time $t_{i-1}$ and $t_i$ respectively.

# %%
spy = np.genfromtxt('spy.csv', skip_header=1, delimiter=',')
aapl=np.genfromtxt('aapl.csv', skip_header=1, delimiter=',')
# last row correspond to the latest values
spyp = spy[:, 5]
aaplp=aapl[:,5]
returnspyp = (spyp[1:] - spyp[:501])/spyp[:501]
returnaaplp = (aaplp[1:] - aaplp[:501])/aaplp[:501]
X=returnspyp
Y=returnaaplp
plt.scatter(X,Y)
plt.xlabel('SPY Closing Prices')
plt.ylabel('AAPL Closing Prices')
print ('Correlation using corrcoeff: ', np.corrcoef(X, Y)[0, 1])
# Out:
# Correlation using corrcoeff:  0.717340630351634

# %% [markdown]
# ### Probability Distribution - Normal Distribution
# A random variable $X \sim \mathcal{N}(\mu,\,\sigma^{2})$ is said to be normally distributed with parameter $\mu$ and $\sigma^2$ if its density is given by
#
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(x - \mu)^2}{2 \sigma^2}} $$
# The normal density function is a bell shaped curve that is symmetric about $\mu$. In practice, many random phenomena have a normal probability distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Plot between mu-5*sigma and mu+5*sigma with .001 steps.
mu = 2.5
sigma =2.0
x_axis = np.arange(mu-5*sigma, mu+5*sigma, 0.001)

plt.plot(x_axis, norm.pdf(x_axis,mu,sigma))
plt.show()

# %% [markdown]
# <h3> Estimate largest catch </h3>
#
# <a href='https://youtu.be/eOMZtBacarY?t=1734' > BBC Video </a>
#
#
# Average number of fish a day = 200
#
# Total number of fish in 40 year:
#
# 40 years * 8 weeks during the year = 320
#
# 320 * 6 days of the week = 1920
#
# 1920 * 200 = 384,000 fish caught in his whole career.
#
#
# Average weight of a fish on the observation day = 220 g
# Standard Deviation based on the observation day =  238 g

# %%
# Plot between mu-5*sigma and mu+5*sigma with .001 steps.
mu = 220
sigma =238
x_axis = np.arange(mu-5*sigma, mu+5*sigma, 0.001)

plt.plot(x_axis, norm.pdf(x_axis,mu,sigma))
plt.show()

# %%
from scipy.stats import norm
prl = norm(220, 238).cdf(1300) # P(W <= 1300)
prg = 1 - prl # P(W > 1300)
print (prg*384000)
# Out:
# 1.0913290703769007

# %% [markdown]
# Exercise 3: Generate 1000 samples from a normal distribution using numpy (see np.random.normal()) with mu = 2 and sigma = 1.0. Plot the histogram along with the normal pdf plot to show the fit along with each plot.

# %%
from scipy.stats import norm
mu,sigma=2,1.0
samp=np.random.normal(mu,sigma,1000)
samp
plt.hist(samp, bins = 25, normed=True, alpha=0.4, color='blue')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
plt.plot(x, p, 'r', linewidth=2)

# %% [markdown]
# Skewed Distribution: A distribution is skewed if one of its tails is longer than the other. A negatively skewed distribution is one when tail on the negative distribution is longer. On the other hand a positively skewed distribution is when the tail on the positive direction is longer.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Most asset return distributions are skewed.
#
# ![image.png](attachment:image.png)

# %%
import scipy.stats as stats

# %%
my_data = np.genfromtxt('resources/GSPC.csv', skip_header=1,delimiter=',')

# %%
np.shape(my_data)
# Out:
# (1260, 7)

# %%
price = my_data[:,5]

# %%
price
# Out:
# array([1461.890015, 1457.150024, 1461.02002 , ..., 2713.060059,
#        2723.98999 , 2743.149902])

# %%
returns = (price[1:] - price[:1259])/price[:1259]

# %%
np.shape(returns)
# Out:
# (1259,)

# %%
print ('Skew:', stats.skew(returns))
print ('Mean:', np.mean(returns))
print ('Median:', np.median(returns))

plt.hist(returns, 30);
# Out:
# Skew: -0.38831219986319604
# Mean: 0.0005279284365265702
# Median: 0.0005452557698998719

# %%
plt.show()

# %%
# jarque bera test whether sample data have the skewness and kurtosis matching a normal distribution
# Samples from a normal distribution have an expected skewness of 0 and an expected excess kurtosis of 0
_, pvalue = stats.jarque_bera(returns)  # testing normality

# %%
pvalue  # typical pvalue > 0.05 indicates likely normal, works  for number of samples > 2000
# Out:
# 0.0

# %%
# another normality test
_, pvalue = stats.kstest(returns, 'norm')

# %%
pvalue
# Out:
# 0.0

# %%
x = np.random.normal(0, 1, 10000)
_, pvalue = stats.jarque_bera(x)
print(pvalue) # > 0.05 most likely normal
# Out:
# 0.07827596054677044

# %%
# another normality test
_, pvalue = stats.kstest(x, 'norm')
print(pvalue) # > 0.05 most likely normal
# Out:
# 0.19772999019626397

# %%
print ('Skew:', stats.skew(x))
print ('Kurtosis:', stats.kurtosis(x))
print ('Mean:', np.mean(x))
print ('Median:', np.median(x))
# Out:
# Skew: -0.05384120288153945
# Kurtosis: 0.02515094914772531
# Mean: 0.010911628754588776
# Median: 0.018027102124240385

# %% [markdown]
# Exercise 4 : Get daily historical data for last five years for your favourite stock from the yahoo finance site. Repeat the above process for computing returns using the adjusted closing price, plot histogram, and perform Jarque-Bera test for normality. Note that the test here is on a smaller number of samples (< 2000), so it is approximate. Also, perform the KS-test.

# %%
msft = np.genfromtxt('msft.csv', skip_header=1, delimiter=',')

# last row correspond to the latest values
msftp = msft[:, 5]

returnspyp = (msftp[1:] - msftp[:1257])/msftp[:1257]
np.shape(returnspyp)
plt.hist(returnspyp,30)
pvalue, _ = stats.jarque_bera(returns)
print('Jarque-Bera test:',pvalue)
pvalue, _ = stats.kstest(returns, 'norm')
print('KS test:',pvalue)
# Out:
# Jarque-Bera test: 447.4429245993955
# KS test: 0.48920007752956685

# %% [markdown]
# Exercise 5: Perform the Jarque-Bera and KS-test on the data1999 and data2012  from 'Introduction to Numpy -II' notebook.

# %%
data1999=np.genfromtxt('resources/US_County_Diabetes_Control_Rate_1999_2012.csv', skip_header=1, delimiter=',')
np.shape(data1999)
data99 = data1999[0:3193,1]
data99.shape
returns1999=(data99[0:] - data99[:3193])/data99[:3193]
print(returns1999)
pvalue, _ = stats.jarque_bera(data99)
pvalue
print('Jarque-Bera test 1999:',pvalue)
pvalue, _ = stats.kstest(data99, 'norm')
print('KS test: 1999',pvalue)
data12=data1999[41511:44703,1]
pvalue12, _ = stats.jarque_bera(data12)
pvalue12k, _ = stats.kstest(data12, 'norm')
print('Jarque-Bera test 2012:',pvalue12)
print('KS test: 2012',pvalue12k)
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# Jarque-Bera test 1999: 677.7536558701364
# KS test: 1999 1.0
# Jarque-Bera test 2012: 1932.3682826868303
# KS test: 2012 1.0
