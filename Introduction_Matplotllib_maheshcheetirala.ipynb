# %% [markdown]
# <h3> Introduction to Matplotlib Package</h3>
# In this section we will learn about matplotlib package that helps you to generate plots, histograms,
# power spectra, bar charts, errorcharts, scatterplots, etc.
# <h3> References </h3>
# <a href="https://matplotlib.org/users/pyplot_tutorial.html"> Matplotlib Tutorial - I </a><br>
# <a href="http://www.python-course.eu/matplotlib.php"> Matplotlib Tutorial - II </a><br>
# <a href="https://github.com/matplotlib/AnatomyOfMatplotlib"> Matplotlib Tutorial - III </a><br>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4],color='lightblue', linewidth=12)
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot?

# %% [markdown]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3].

# %%
plt.plot([1,2,3,4], [1,4,9,16], '--')  # default is "-" solid line
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# The axis() command in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.

# %% [markdown]
# Exercise: Repeat the above plot by creating y values using np.random.randint(1, 20, size=4)

# %%
yvalues=np.random.randint(1, 20, size=4)
plt.plot([1,2,3,4], yvalues, 'ro')  # default is "-" solid line
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)
t
# multiple plots 
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.plot(days, celsius_min,
         days, celsius_min, "oy",
         days, celsius_max, 
         days, celsius_max, "or")
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
plt.scatter?

# %%
plt.scatter('a', 'b', c='c', s='d', data=data) #color mapping from data['c'] and size: data['d']
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color)
plt.show()

# %% [markdown]
# #### Color Maps
# Change colormaps
# https://matplotlib.org/examples/color/colormaps_reference.html

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='Greys')
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='YlOrRd') 
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='YlOrRd_r') 
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
#sz = [8, 16, 32, 64]
sz = [8, 32, 128, 256]  #area
plt.scatter(x, y, c='blue', s=sz)  
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# Exercise: For the above plot change the color of the circle based on the size.

# %%
x = [1,2,3,4]
y = [1,4,9,16]
#sz = [8, 16, 32, 64]
sz = [8, 32, 128, 256]  #area
plt.scatter(x, y, c=sz, s=sz)  
plt.axis([0, 6, 0, 20])
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
#sz = [8, 16, 32, 64]
sz = [8, 32, 128, 256]  #area
plt.scatter(x, y, color='Blue', s=sz)  
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# multiple subplots 
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(211) # numrows, numcols, fignum (1 to 2) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
# multiple subplots 
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(221) # numrows, numcols, fignum (1 to 4) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(224)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# Exercise: Modify the above code to have the following plot.
# ![image.png](attachment:image.png)

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(221) # numrows, numcols, fignum (1 to 4) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(222)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(223)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.subplot(224)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
X = [ (2,1,1), (2,3,4), (2,3,5), (2,3,6) ]
#X = [ (2,1,1), (2,3,1), (2,3,2), (2,3,3) ]
#X = [ (2,1,1), (2,1,2)]
plt.figure(figsize=(12, 6))
for nrows, ncols, plot_number in X:
    plt.subplot(nrows, ncols, plot_number)
plt.show()

# %% [markdown]
# ### More control using gridspec

# %%
#https://matplotlib.org/users/gridspec.html#a-complex-nested-gridspec-using-subplotspec
from matplotlib.gridspec import GridSpec

# %%
plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2, 0))
ax5 = plt.subplot2grid((3,3), (2, 1))

plt.suptitle("subplot2grid")
plt.show()

# %%
plt.figure()

gs = GridSpec(3, 3)
ax1 = plt.subplot(gs[0, :])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0,0), colspan=3))
ax2 = plt.subplot(gs[1,:-1])
ax3 = plt.subplot(gs[1:, -1])
ax4 = plt.subplot(gs[-1,0])
ax5 = plt.subplot(gs[-1,-2])

plt.suptitle("GridSpec")
plt.show()

# %%
plt.figure()

gs = GridSpec(3, 3)
ax1 = plt.subplot(gs[0, :])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0,0), colspan=3))
ax2 = plt.subplot(gs[1,0:2])
ax3 = plt.subplot(gs[1:3, 2])
ax4 = plt.subplot(gs[2,0])
ax5 = plt.subplot(gs[2,1])
plt.suptitle("GridSpec")
plt.show()

# %% [markdown]
# #### Working with text
# The text() command can be used to add text in an arbitrary location, and the xlabel(), ylabel() and title() are used to add text in the indicated locations. Any text element can use math text. You should use raw strings (precede the quotes with an 'r'), and surround the math text with dollar signs ($), as in TeX.

# %%
plt.text?

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, _ = plt.hist(x, 50, normed=1)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# #### Annotating text
# A common use for text is to annotate some feature of the plot, and the annotate() method provides helper functionality to make annotations easy. In an annotation, there are two points to consider: the location being annotated represented by the argument xy and the location of the text xytext. Both of these arguments are (x,y) tuples.

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# Exercise: Modify the above code to annotate the local min.

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
plt.plot(t, s, lw=2)

plt.annotate('local min', xy=(0.5, -1), xytext=(1, -1),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)

# %%
print (X[0:5, 0:5])
print (Y[0:5, 0:5])
# Out:
# [[-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]
#  [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]
#  [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]
#  [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]
#  [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]]
# [[-3.         -3.         -3.         -3.         -3.        ]
#  [-2.93939394 -2.93939394 -2.93939394 -2.93939394 -2.93939394]
#  [-2.87878788 -2.87878788 -2.87878788 -2.87878788 -2.87878788]
#  [-2.81818182 -2.81818182 -2.81818182 -2.81818182 -2.81818182]
#  [-2.75757576 -2.75757576 -2.75757576 -2.75757576 -2.75757576]]

# %%
Z = np.sqrt(X**2 + Y**2)
print (Z[0:5, 0:5])
# Out:
# [[4.24264069 4.20000437 4.15781429 4.11608415 4.0748281 ]
#  [4.20000437 4.15693077 4.11429901 4.07212297 4.03041695]
#  [4.15781429 4.11429901 4.07122086 4.02859385 3.98643245]
#  [4.11608415 4.07212297 4.02859385 3.98551095 3.94288889]
#  [4.0748281  4.03041695 3.98643245 3.94288889 3.89980104]]

# %%
plt.figure()
cp = plt.contourf(X, Y, Z)
#cp = plt.contourf(X, Y, Z,cmap='YlOrRd')
plt.colorbar(cp)
plt.title('Filled Contours Plot')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %% [markdown]
# Exercise: Modify the contour code to create a non-filled contour plot like:
# ![image.png](attachment:image.png)
#
# Hint: Use plt.contour() and plt.clabel()

# %%
import matplotlib.pyplot as plt
plt.figure()
c = ('#ff0000', '#ffff00', '#0000FF', '0.6', 'c', 'm')
cp = plt.contour(X, Y, Z)# f means contour is filled with colours and without f gives the unfilled contours.
plt.clabel(cp, inline=True, 
          fontsize=10)
plt.title('Contour Plot')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure()
contour = plt.contourf(X, Y, Z)
c = ('#ff0000', '#ffff00', '#0000FF', '0.6', 'c', 'm')# adding contour plot with individual colours. This is for practising.
contour_filled = plt.contourf(X, Y, Z, colors=c)
plt.colorbar(contour)
plt.clabel(cp, inline=True, 
          fontsize=10)
plt.title('Contour Plot')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %% [markdown]
# #### plt.imshow()
# Using interpolation

# %%
A = np.random.rand(5, 5)
plt.imshow?

# %%
plt.figure(1)
plt.imshow(A, interpolation='bilinear')
#plt.imshow(A, interpolation='none')
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise: Repeat the above plot with a different colormap

# %%
plt.figure(1)
plt.imshow(A, interpolation='bilinear',cmap='YlOrRd')
plt.imshow(A, interpolation='none',cmap='YlOrRd')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Plot Heat Map - Correlation Matrix

# %%
import pandas as pd, pandas_datareader.data as data
from datetime import datetime as dt

# %%
stocks_data = pd.read_csv('resources/stock_px_2.csv',
                           parse_dates=True, index_col=0)
print(stocks_data.head())
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93

# %%
# calculate percentage change using pandas functions pct_change()
stocks_pct_change = stocks_data.pct_change()
stocks_pct_change.head()
# Out:
#                 AAPL      MSFT       XOM       SPX
# 2003-01-02       NaN       NaN       NaN       NaN
# 2003-01-03  0.006757  0.001421  0.000684 -0.000484
# 2003-01-06  0.000000  0.017975  0.024624  0.022474
# 2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
# 2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086

# %%
# calculate Pearson Correlation using pandas function corr()
corr_stocks = stocks_pct_change.corr()
corr_stocks
# Out:
#           AAPL      MSFT       XOM       SPX
# AAPL  1.000000  0.444697  0.385927  0.564474
# MSFT  0.444697  1.000000  0.534691  0.714763
# XOM   0.385927  0.534691  1.000000  0.764643
# SPX   0.564474  0.714763  0.764643  1.000000

# %%
plt.figure(figsize=(12, 10))
plt.imshow(corr_stocks, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr_stocks)), corr_stocks.columns, rotation='vertical')
plt.yticks(range(len(corr_stocks)), corr_stocks.columns);
plt.suptitle('Stock Correlations Heat Map', fontsize=15, fontweight='bold')
plt.show()
